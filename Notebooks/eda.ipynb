# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../data/sales_data.csv')

# Preview
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    Order ID        Date Product  Category  Quantity  Unit Price  Total Sales  \
# 0         1  2023-01-21    Rice   Grocery         8         800         6400
# 1         2  2023-04-10  Jacket  Clothing         8         472         3776
# 2         3  2023-10-21  Comics     Books         8         591         4728
# 3         4  2023-11-10    Rice   Grocery         1         559          559
# 4         5  2023-02-28    Rice   Grocery         1         574          574
#
#   Region Customer ID
# 0   East    CUST7265
# 1   West    CUST9322
# 2  South    CUST6311
# 3  South    CUST7396
# 4   East    CUST8849
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order ID     500 non-null    int64
#  1   Date         500 non-null    object
#  2   Product      500 non-null    object
#  3   Category     500 non-null    object
#  4   Quantity     500 non-null    int64
#  5   Unit Price   500 non-null    int64
#  6   Total Sales  500 non-null    int64
#  7   Region       500 non-null    object
#  8   Customer ID  500 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 35.3+ KB
# None
#          Order ID    Quantity  Unit Price  Total Sales
# count  500.000000  500.000000  500.000000   500.000000
# mean   250.500000    5.094000  549.092000  2756.844000
# std    144.481833    2.641803  259.381173  2027.254513
# min      1.000000    1.000000  102.000000   125.000000
# 25%    125.750000    3.000000  326.000000  1084.500000
# 50%    250.500000    5.000000  557.000000  2302.000000
# 75%    375.250000    7.000000  766.000000  3880.250000
# max    500.000000    9.000000  999.000000  8793.000000

# %%
# Total Sales by Category
category_sales = df.groupby('Category')['Total Sales'].sum().sort_values(ascending=False)
category_sales.plot(kind='bar', title='Total Sales by Category', color='skyblue')
plt.ylabel('Sales Amount')
plt.tight_layout()
plt.savefig('../images/sales_by_category.png')
plt.show()

# %%
# Monthly Sales Trend
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
monthly_sales = df.resample('M')['Total Sales'].sum()
monthly_sales.plot(title='Monthly Sales Trend', marker='o')
plt.ylabel('Total Sales')
plt.grid(True)
plt.tight_layout()
plt.savefig('../images/monthly_sales_trend.png')
plt.show()
# Out:
# C:\Users\dhive\AppData\Local\Temp\ipykernel_5996\4071338824.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df.resample('M')['Total Sales'].sum()
